# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook outlines the steps for performing EDA using Python in a Jupyter Notebook. We will use libraries such as Pandas, Matplotlib, and Seaborn to analyze the dataset.
#
# ## 1. Install Necessary Libraries
#
# If you haven't installed the required libraries yet, run the following command in a Jupyter Notebook cell:

# %% [markdown]
# !pip install pandas matplotlib seaborn missingno

# %%
# !pip install pandas matplotlib seaborn missingno
# Out:
# Requirement already satisfied: pandas in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (0.13.2)
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from missingno) (1.16.3)
# Requirement already satisfied: six>=1.5 in c:\users\my device\desktop\kaim pro\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2

# %% [markdown]
# ## 2. Import Libraries
#
# Now we will import the necessary libraries.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'
